# %%
import pydot
import os
import random
import operator
import numpy as np
from collections import Counter
from PIL import Image

# %%
classes = {"DummyStart":0,"ACCESS_MASK":1,"Atom":2,"BOOLEAN":3,"Debug":4,"Device":5,
                                 "Environment":6,"File":7,"HANDLE":8,"Job":9,"LONG":10,"LPC":11,
                                 "Memory":12,"NTSTATUS":13,"Object":14,"Other":15,"PHANDLE":16,
                                 "PLARGE_INTEGER":17,"Process":18,"PUNICODE_STRING":19,
                                 "PULONG":20,"PULARGE_INTEGER":21,"PVOID_SIZEAFTER":22,
                                 "PWSTR":23,"Registry":24,"Security":25,"Synchronization":26,
                                 "Time":27,"Transaction":28,"ULONG":29,"WOW64":30, "DummyEnd":31}

# %%
path = "/home/achilleas/Desktop/thesis/DATASET F1/Fold_1/80%_train"
filename = "default_G_tone_cardinality"
mapFilename = "default_unique_mapping"
rootDir = [os.path.join(root, name)
             for root, dirs, files in os.walk(path)
             for name in files
             if name.endswith(filename+".txt")]
print(len(rootDir))
map_dir = [os.path.join(root, name)
              for root, dirs, files in os.walk(path)
              for name in files
              if name.endswith(mapFilename+".txt")]
# Out:
# 2127

# %%
try:
    os.mkdir("media")
except OSError:
    print ("Creation of the directory %s failed" % "media")
else:
    print ("Successfully created the directory %s" % "media")
# Out:
# Creation of the directory media failed

# %%
def createBucket(path):
    bucket = {}
    with open(path) as fp:
        line = fp.readline()
        i=0
        while line : 
            bucket[i] = line
            i += 1
            line = fp.readline()
    print(bucket)

# %%
def graphCreate(path) :
    G = pydot.Dot(graph_type='digraph')
    vir_hash = path.split("/")[-2]
    family = path.split("/")[-3]
    nodes = {}
    nodes_counter = {}
    edge_list = {}

    cnt = 1 
    with open(path) as fp:
        line = fp.readline()
        while line :
            parent_id = line.split(',')[0]
            child_id = line.split(',')[1]
            if parent_id not in nodes :
                nodes[parent_id] = pydot.Node(parent_id, style = "filled", color= "green")
                nodes_counter[nodes[parent_id]]=1
            else :
                nodes_counter[nodes[parent_id]]+=1
            if child_id not in nodes :
                nodes[child_id] =pydot.Node(child_id, style = "filled", color= "red")
                nodes_counter[nodes[child_id]] =1
            else: 
                nodes_counter[nodes[child_id]]+=1
            temp_edge = parent_id+"*"+child_id
            if temp_edge in edge_list: 
                edge_list[temp_edge] += 1            
            else : 
                edge_list[temp_edge] = 1
    #         edge = pydot.Edge(nodes[parent_id], nodes[child_id])
    #         edge_list.append(edge)
            line = fp.readline()
        sorted_n = sorted(nodes_counter.items(), key = lambda kv: kv[1])
        fp.close()
    for n in sorted_n:
        G.add_node(n[0])
    for e in edge_list:
        expected_edge = pydot.Edge(e.split('*')[0], e.split('*')[1], label = edge_list[e])
        G.add_edge(expected_edge)
    return [G, vir_hash, filename, family]

# %%
def displayGraph (G , vir_hash, filename, dir_dst):
    from IPython.display import Image, display
    im = Image(G.create_png())
    try:
        os.mkdir("media/"+dir_dst)
    except OSError:
        print ("Creation of the directory %s failed" % dir_dst)
    else:
        print ("Successfully created the directory %s" % dir_dst)
    G.write_png("media/"+dir_dst+ '/' + vir_hash+".png")
#     display(im)

# %%
def visualizeAllData():
    for paths in rootDir:
        Grf = graphCreate(paths)
        displayGraph(Grf[0],Grf[1],Grf[2], Grf[3])

# %%
def visualizeOne(path):
    print(rootDir.index(path))
    print(path)
    print(len(rootDir))
    displayGraph(graphCreate(path)[0],graphCreate(path)[1],graphCreate(path)[2], graphCreate(path)[3])

# %%
def countPngs():
    return len([os.path.join(root, name)
             for root, dirs, files in os.walk("media")
             for name in files
             if name.endswith('.png')])

# %%
# visualizeOne(rootDir[random.randrange(len(rootDir))])
# createBucket(map_dir[random.randrange(len(map_dir))])
visualizeAllData()
# countPngs()
# visualizeOne(rootDir[0])
# Out:
# Creation of the directory ZZSkype,Skype failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory Prorat,AVW, failed
# Creation of the directory DKI,PoisonIvy, failed
# Creation of the directory DKI,PoisonIvy, failed
# Creation of the directory DKI,PoisonIvy, failed
# Creation of the directory DKI,PoisonIvy, failed
# Creation of the directory DKI,PoisonIvy, failed
# Creation of the directory DKI,PoisonIvy, failed
# Creation of the directory DKI,PoisonIvy, failed
# Creation of the directory DKI,PoisonIvy, failed
# Creation of the directory DKI,PoisonIvy, failed
# Creation of the directory DKI,PoisonIvy, failed
# Creation of the directory DKI,PoisonIvy, failed
# Creation of the directory DKI,PoisonIvy, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Creation of the directory Allaple,RAHack, failed
# Successfully created the directory ZZAdobe_Reader,Adobe_Reader
# Creation of the directory VS,INService, failed
# Creation of the directory VS,INService, failed
# Creation of the directory VS,INService, failed
# Creation of the directory VS,INService, failed
# Creation of the directory VS,INService, failed
# Creation of the directory VS,INService, failed
# Creation of the directory VS,INService, failed
# Creation of the directory VS,INService, failed
# Creation of the directory VS,INService, failed
# Creation of the directory VS,INService, failed
# Creation of the directory VS,INService, failed
# Creation of the directory VS,INService, failed
# Creation of the directory VS,INService, failed
# Creation of the directory VS,INService, failed
# Creation of the directory Bobax,Bobic, failed
# Creation of the directory Bobax,Bobic, failed
# Creation of the directory Bobax,Bobic, failed
# Creation of the directory Bobax,Bobic, failed
# Creation of the directory Bobax,Bobic, failed
# Creation of the directory Bobax,Bobic, failed
# Creation of the directory Bobax,Bobic, failed
# Creation of the directory Bobax,Bobic, failed
# Creation of the directory Bobax,Bobic, failed
# Creation of the directory Bobax,Bobic, failed
# Creation of the directory Bobax,Bobic, failed
# Creation of the directory Bobax,Bobic, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Creation of the directory Zlob,Puper, failed
# Successfully created the directory ZZping,ping
# Successfully created the directory ZZChrome_Setup,Chrome_Setup
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Banker,Banker, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory Swizzor,Obfuscated, failed
# Creation of the directory OnLineGames,OnlineGames, failed
# Creation of the directory OnLineGames,OnlineGames, failed
# Creation of the directory OnLineGames,OnlineGames, failed
# Creation of the directory OnLineGames,OnlineGames, failed
# Creation of the directory OnLineGames,OnlineGames, failed
# Creation of the directory OnLineGames,OnlineGames, failed
# Creation of the directory OnLineGames,OnlineGames, failed
# Creation of the directory OnLineGames,OnlineGames, failed
# Creation of the directory OnLineGames,OnlineGames, failed
# Creation of the directory OnLineGames,OnlineGames, failed
# Creation of the directory OnLineGames,OnlineGames, failed
# Creation of the directory OnLineGames,OnlineGames, failed
# Creation of the directory OnLineGames,OnlineGames, failed
# Creation of the directory OnLineGames,OnlineGames, failed
# Creation of the directory OnLineGames,OnlineGames, failed
# Creation of the directory OnLineGames,OnlineGames, failed
# Creation of the directory OnLineGames,OnlineGames, failed
# Creation of the directory OnLineGames,OnlineGames, failed
# Successfully created the directory ZZTux_Racer,Tux_Racer
# Successfully created the directory ZZChrome,Chrome
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Creation of the directory Virut,Virut, failed
# Successfully created the directory ΖΖNetcat_port_listen,Netcat_port_listen
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Creation of the directory Plemood,Pupil, failed
# Successfully created the directory ΖΖInternet_Explorer,Internet_Explorer
# Successfully created the directory ZZTask_Manager,Task_Manager
# Creation of the directory Downloader,Agent, failed
# Creation of the directory Downloader,Agent, failed
# Creation of the directory Downloader,Agent, failed
# Creation of the directory Downloader,Agent, failed
# Creation of the directory Downloader,Agent, failed
# Creation of the directory Downloader,Agent, failed
# Creation of the directory Downloader,Agent, failed
# Creation of the directory Downloader,Agent, failed
# Creation of the directory Downloader,Agent, failed
# Creation of the directory Downloader,Agent, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory IRCBot,Sdbot, failed
# Creation of the directory Nilage,Lineage, failed
# Creation of the directory Nilage,Lineage, failed
# Creation of the directory Nilage,Lineage, failed
# Creation of the directory Nilage,Lineage, failed
# Creation of the directory Nilage,Lineage, failed
# Creation of the directory Nilage,Lineage, failed
# Creation of the directory Nilage,Lineage, failed
# Creation of the directory Nilage,Lineage, failed
# Creation of the directory Nilage,Lineage, failed
# Creation of the directory Nilage,Lineage, failed
# Creation of the directory Nilage,Lineage, failed
# Creation of the directory Nilage,Lineage, failed
# Creation of the directory Nilage,Lineage, failed
# Creation of the directory Nilage,Lineage, failed
# Creation of the directory Nilage,Lineage, failed
# Creation of the directory Nilage,Lineage, failed
# Creation of the directory Nilage,Lineage, failed
# Creation of the directory Nilage,Lineage, failed
# Creation of the directory Nilage,Lineage, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Bancos,Banker, failed
# Creation of the directory Downloader,VB, failed
# Creation of the directory Downloader,VB, failed
# Creation of the directory Downloader,VB, failed
# Creation of the directory Downloader,VB, failed
# Creation of the directory Downloader,VB, failed
# Creation of the directory Downloader,VB, failed
# Creation of the directory Downloader,VB, failed
# Creation of the directory Downloader,VB, failed
# Creation of the directory Downloader,VB, failed
# Creation of the directory Downloader,VB, failed
# Creation of the directory Downloader,VB, failed
# Creation of the directory Downloader,VB, failed
# Creation of the directory Downloader,VB, failed
# Creation of the directory Downloader,VB, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory SdBot,Sdbot, failed
# Creation of the directory OnLineGames,Mmorpg, failed
# Creation of the directory OnLineGames,Mmorpg, failed
# Creation of the directory OnLineGames,Mmorpg, failed
# Creation of the directory OnLineGames,Mmorpg, failed
# Creation of the directory OnLineGames,Mmorpg, failed
# Creation of the directory OnLineGames,Mmorpg, failed
# Creation of the directory OnLineGames,Mmorpg, failed
# Creation of the directory OnLineGames,Mmorpg, failed
# Creation of the directory OnLineGames,Mmorpg, failed
# Creation of the directory OnLineGames,Mmorpg, failed
# Creation of the directory OnLineGames,Mmorpg, failed
# Creation of the directory OnLineGames,Mmorpg, failed
# Creation of the directory OnLineGames,Mmorpg, failed
# Creation of the directory OnLineGames,Mmorpg, failed
# Creation of the directory OnLineGames,Mmorpg, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory Banbra,Banker, failed
# Creation of the directory ABU,Banload, failed
# Creation of the directory ABU,Banload, failed
# Creation of the directory ABU,Banload, failed
# Creation of the directory ABU,Banload, failed
# Creation of the directory ABU,Banload, failed
# Creation of the directory ABU,Banload, failed
# Creation of the directory ABU,Banload, failed
# Creation of the directory ABU,Banload, failed
# Creation of the directory ABU,Banload, failed
# Creation of the directory ABU,Banload, failed
# Creation of the directory ABU,Banload, failed
# Creation of the directory ABU,Banload, failed
# Creation of the directory ABU,Banload, failed
# Successfully created the directory ZZAutoruns,Autoruns
# Creation of the directory Ardamax,Ardamax, failed
# Creation of the directory Ardamax,Ardamax, failed
# Creation of the directory Ardamax,Ardamax, failed
# Creation of the directory Ardamax,Ardamax, failed
# Creation of the directory Ardamax,Ardamax, failed
# Creation of the directory Ardamax,Ardamax, failed
# Creation of the directory Ardamax,Ardamax, failed
# Creation of the directory Ardamax,Ardamax, failed
# Creation of the directory Ardamax,Ardamax, failed
# Creation of the directory Ardamax,Ardamax, failed
# Creation of the directory Ardamax,Ardamax, failed
# Creation of the directory Ardamax,Ardamax, failed
# Creation of the directory Ardamax,Ardamax, failed
# Creation of the directory Ardamax,Ardamax, failed
# Creation of the directory Ardamax,Ardamax, failed
# Creation of the directory Ardamax,Ardamax, failed
# Creation of the directory Ardamax,Ardamax, failed
# Creation of the directory Ardamax,Ardamax, failed
# Creation of the directory Ardamax,Ardamax, failed
# Creation of the directory Ardamax,Ardamax, failed
# Successfully created the directory ΖΖNetcat_port_scan,Netcat_port_scan
# Successfully created the directory ZZApple_Software_Update,Apple_Software_Update
# Successfully created the directory ZZCopy_to_system_folder,Copy_to_system_folder
# Creation of the directory Downloader,Delf, failed
# Creation of the directory Downloader,Delf, failed
# Creation of the directory Downloader,Delf, failed
# Creation of the directory Downloader,Delf, failed
# Creation of the directory Downloader,Delf, failed
# Creation of the directory Downloader,Delf, failed
# Creation of the directory Downloader,Delf, failed
# Creation of the directory Downloader,Delf, failed
# Creation of the directory Downloader,Delf, failed
# Creation of the directory Downloader,Delf, failed
# ...
# Successfully created the directory ZZOpenOffice_Writer,OpenOffice_Writer
# Successfully created the directory ΖΖNetHack,NetHack
# Creation of the directory Mydoom,Mydoom, failed
# Creation of the directory Mydoom,Mydoom, failed
# Creation of the directory Mydoom,Mydoom, failed
# Creation of the directory Mydoom,Mydoom, failed
# Creation of the directory Mydoom,Mydoom, failed
# Creation of the directory Mydoom,Mydoom, failed
# Creation of the directory Mydoom,Mydoom, failed
# Creation of the directory Mydoom,Mydoom, failed
# Creation of the directory Mydoom,Mydoom, failed
# Creation of the directory Mydoom,Mydoom, failed
# Creation of the directory Mydoom,Mydoom, failed
# Creation of the directory Mydoom,Mydoom, failed
# Successfully created the directory ΖΖHello_world,Hello_world
# Successfully created the directory ZZSelf_extracting_archive,Self_extracting_archive
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Small,Downloader, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Hupigon,AWQ, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Creation of the directory Parite,Pate, failed
# Successfully created the directory ΖΖFreeciv,Freeciv
# Creation of the directory Lmir,LegMir, failed
# Creation of the directory Lmir,LegMir, failed
# Creation of the directory Lmir,LegMir, failed
# Creation of the directory Lmir,LegMir, failed
# Creation of the directory Lmir,LegMir, failed
# Creation of the directory Lmir,LegMir, failed
# Creation of the directory Lmir,LegMir, failed
# Creation of the directory Lmir,LegMir, failed
# Creation of the directory Lmir,LegMir, failed
# Creation of the directory Lmir,LegMir, failed
# Creation of the directory Lmir,LegMir, failed
# Creation of the directory Lmir,LegMir, failed
# Creation of the directory Lmir,LegMir, failed
# Creation of the directory Lmir,LegMir, failed
# Creation of the directory Lmir,LegMir, failed
# Creation of the directory Lmir,LegMir, failed
# Creation of the directory Lmir,LegMir, failed
# Creation of the directory Lmir,LegMir, failed
# Creation of the directory LdPinch,LDPinch, failed
# Creation of the directory LdPinch,LDPinch, failed
# Creation of the directory LdPinch,LDPinch, failed
# Creation of the directory LdPinch,LDPinch, failed
# Creation of the directory LdPinch,LDPinch, failed
# Creation of the directory LdPinch,LDPinch, failed
# Creation of the directory LdPinch,LDPinch, failed
# Creation of the directory LdPinch,LDPinch, failed
# Creation of the directory LdPinch,LDPinch, failed
# Creation of the directory LdPinch,LDPinch, failed
# Creation of the directory LdPinch,LDPinch, failed
# Creation of the directory LdPinch,LDPinch, failed
# Creation of the directory LdPinch,LDPinch, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
# Creation of the directory PolyCrypt,Swizzor, failed
